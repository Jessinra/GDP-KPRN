# %% [markdown]
#  # **Test KPRN Result**

# %%
TEST_CODE = "2019-07-19 05:47:47"
MODEL_DIR = "../logs/{}".format(TEST_CODE)
CHOSEN_EPOCH = 5

MAX_SEED_NUM = 3
MAX_RELATION_NUM = 15

# %% [markdown]
# # > Config

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.log_device_placement = True

sess = tf.Session(config=config)
set_session(sess)
# Out:
# Using TensorFlow backend.

# %%
from tqdm import tqdm

# %% [markdown]
# # > Load model

# %%
import os
trained_weights = sorted(os.listdir(MODEL_DIR))
choosen_weight = "{}/{}".format(MODEL_DIR, trained_weights[CHOSEN_EPOCH - 1])

# %%
from keras.models import load_model
from keras.models import Model

model = load_model(choosen_weight);
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0725 11:02:18.091543 140396732733184 deprecation_wrapper.py:119] From /home/jessinra/.local/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0725 11:02:18.096777 140396732733184 deprecation_wrapper.py:119] From /home/jessinra/.local/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0725 11:02:18.121473 140396732733184 deprecation_wrapper.py:119] From /home/jessinra/.local/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0725 11:02:18.232672 140396732733184 deprecation_wrapper.py:119] From /home/jessinra/.local/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0725 11:02:18.242723 140396732733184 deprecation.py:506] From /home/jessinra/.local/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0725 11:02:18.627855 140396732733184 deprecation_wrapper.py:119] From /home/jessinra/.local/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0725 11:02:19.392277 140396732733184 deprecation_wrapper.py:119] From /home/jessinra/.local/lib/python3.5/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0725 11:02:19.403743 140396732733184 deprecation.py:323] From /home/jessinra/.local/lib/python3.5/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# # > Load data

# %% [markdown]
# ## >> Read data

# %%
file_ratings_re = open("../data/ratings_re.csv").readlines()
file_triples_idx = open("../data/triples_idx.txt").readlines()

file_moviesIdx = open("../data/moviesIdx.txt").readlines() 
file_types = open("../data/types.txt").readlines() 
file_entities = open("../data/entities.txt").readlines()
file_relations = open("../data/relations.txt").readlines()

# %%
# create entity id -> name mapping

entity_id_to_name = {}
for line in file_moviesIdx:
    movie_title, entity_id = line.strip().split()
    entity_id_to_name[entity_id] = movie_title
    
for line in file_entities:
    entity_name, entity_id = line.strip().split()
    entity_id_to_name[entity_id] = entity_name

# %%
# create movie title -> entity type mapping and list of entity for each type

movie_title_to_entity_type = {}
entity_list_with_type = {}

for line in file_types:
    
    # movie title -> entity type
    entity, entity_type = line.strip().split('\t')
    movie_title_to_entity_type[entity] = entity_type
    
    # entity for each type
    if entity_type not in entity_list_with_type:
        entity_list_with_type[entity_type] = []
    
    entity_list_with_type[entity_type].append(entity)

# %%
# Create relation id to name mapping

relation_id_to_name = {}
for line in file_relations:
    relation_name, relation_id = line.strip().split()
    relation_id = int(relation_id)
    relation_id += 200000
    
    # last 2 relation : spouse and relative has no inverse
    if relation_id < 200023:
        relation_id_to_name[str(relation_id + 1)] = relation_name + "_inverse"
    
    relation_id_to_name[str(relation_id)] = relation_name

# %%
list_of_type = [
    "Category",
    "Company",
    "Country",
    "Genre",
    "Movie",
    "Person",
    "User",
    
    "#PAD_TOKEN",
    "#UNK_ENTITY_TYPE",
]

entity_type_to_id = {}
list_of_type_with_id = []

i = 0
for t in list_of_type:
    
    entity_type_to_id[t] = i
    list_of_type_with_id.append("{}\t{}".format(t, i))
    
    i += 1

# %%
# Load KG from cache

import pickle
kg_path = pickle.load(open("../data/cache_kg_path", "rb"))

# %%
user_entity_id_padding = 500000
relation_rated_good_by_id = '200026'
relation_given_good_rating_id = '200027'
good_movie_rating_threshold = 4

# %% [markdown]
# ## >> Prepare data

# %%
import threading

# %%
IRREGULAR_RELATION = ['200024', '200025']
NUM_OF_ITEMS = len(file_moviesIdx)

def generate_path_from_entity_to_all_others(entity_id, keep_relation_ratio=0.5, max_relation_num=30, max_entity_per_relation=1):

    generated_paths = []
    
    r1 = kg_path[entity_id]
    for e2_id in range(0, NUM_OF_ITEMS):
        e2_id = str(e2_id)
        # Skip if e1 == e2 (path to itself)
        if e2_id == entity_id:
            continue

        r2 = kg_path[e2_id]
        intersect_relations = set(r1.keys()).intersection(set(r2.keys()))
        
        # downsample relation
        if len(intersect_relations) < max_relation_num:
            n_intersect_relation = len(intersect_relations)
        else:
            n_intersect_relation = max(max_relation_num, int(len(intersect_relations) * keep_relation_ratio))
            
        intersect_relations = list(intersect_relations)
        np.random.shuffle(intersect_relations)

        for relation in intersect_relations[:n_intersect_relation]:

            t1 = r1[relation]
            t2 = r2[relation]
            intersect_entity = list(set(t1).intersection(set(t2)))
            np.random.shuffle(intersect_entity)
            
            for mid_entity in intersect_entity[:max_entity_per_relation]:
                
                inverse_relation = relation if (relation in IRREGULAR_RELATION) else str(int(relation) + 1)        
                path = "{} {} {} {} {}".format(entity_id, relation, mid_entity, inverse_relation, e2_id)
                generated_paths.append(path)
    
    return generated_paths

# %%
def run_thread(thread_id, thread_items, result):
    for item_id in (thread_items):
        result += generate_path_from_entity_to_all_others(item_id, keep_relation_ratio=0.5, max_relation_num=MAX_RELATION_NUM, max_entity_per_relation=1)
            
def generate_all_path_from_user(user_id, max_seed_num=10, max_seed_ratio=0.2):
    
    user_interacted_items = []
    for relation in kg_path[user_id]:
        user_interacted_items += kg_path[user_id][relation]
    
    user_interacted_items = sorted(set(user_interacted_items))
    
    # downsample seeds
    if len(user_interacted_items) < max_seed_num:
        n_seed = len(user_interacted_items)
    else:
        n_seed = max(max_seed_num, int(len(user_interacted_items) * max_seed_ratio))
    
    # Randomize
    np.random.shuffle(user_interacted_items)
    user_interacted_items = user_interacted_items[:n_seed]
    
    # ====== Threading ======
    user_paths = []
    threads = []
    for i in range(0, n_seed):
        
        # Split item id equally
        thread_items = user_interacted_items[i::n_seed]
        thread = threading.Thread(target=run_thread, args=(i, thread_items, user_paths))    
        thread.start()
        threads.append(thread)
    
    for i in range(0, n_seed):
        threads[i].join()
        
    user_paths = ["{} {} {}".format(user_id, "200027", x) for x in user_paths]
    return user_paths

# %%
def get_type_from_entity_id(entity_id):
    
    # user
    if int(entity_id) > user_entity_id_padding:
        return "User"
    elif entity_id_to_name[entity_id] in movie_title_to_entity_type:
        return movie_title_to_entity_type[entity_id_to_name[entity_id]]
    else:
        return "#UNK_ENTITY_TYPE"

# %%
import numpy as np

END_RELATION = '200030'
GIVEN_RATING_RELATION = '200027'
BATCH_COUNT = 72

def reformat_user_path(user_paths):
    
    new_paths = []
    labels = []
    
    for path in user_paths:
        e1, r1, e2, r2, e3, r3, e4 = path.strip().split()

        t1 = entity_type_to_id[get_type_from_entity_id(e1)]
        t2 = entity_type_to_id[get_type_from_entity_id(e2)]
        t3 = entity_type_to_id[get_type_from_entity_id(e3)]
        t4 = entity_type_to_id[get_type_from_entity_id(e4)]

        r4 = END_RELATION

        entity_rated = kg_path[e1][GIVEN_RATING_RELATION]
        label = 1 if e4 in entity_rated else 0
        
        new_paths.append([
            [e1, t1, r1],
            [e2, t2, r2],
            [e3, t3, r3],
            [e4, t4, r4],
        ])
        
        labels.append(label)
        
    return np.array(new_paths).astype('int'), np.array(labels).astype('int')

# %%
def path_to_string(paths):
    string_paths = []
    for path in paths:
        
        entity_string = []
        for entity in path.split():
            entity_string.append(get_entity_name(str(entity)))
        entity_string = " -> ".join(entity_string)
        
        string_paths.append(entity_string)

    return string_paths

# %% [markdown]
# # > Evaluation

# %% [markdown]
# ## >> Evaluation function

# %%
def _get_k_prediction(X_test, y_pred, k=10, get_best=True, max_pooling_size=-1):
    """
    max_pooling_size -1 means without pooling
    """
    if max_pooling_size > 0:
        return _get_top_k_items_with_score_pooling(X_test, y_pred, k=10, max_pooling_size=max_pooling_size, get_best=get_best)
    else:
        return _get_top_k_items_without_score_pooling(X_test, y_pred, k=10, get_best=get_best)

def _get_top_k_items_without_score_pooling(X_test, y_pred, k=10, get_best=True):
    """
    Get the top-k items from X_test based on y_pred scores, 
    pick all path in sorted X_test until the amount of unique items is equal to k
    """
    choosen_paths = []
    choosen_items = set()

    path_scores = sorted(zip(X_test, y_pred), key=lambda x: x[1], reverse=get_best)
    for path, score in path_scores:
        choosen_paths.append((path, score))
        choosen_items.add(path[3][0]) # Add the last item
        
        if len(choosen_items) >= k:
            break
            
    return choosen_paths, choosen_items

def _get_top_k_items_with_score_pooling(X_test, y_pred, k=10, max_pooling_size=5, get_best=True):
    """
    Get the top-k items from X_test based on averaged y_pred scores,
    pick 'max_pooling_size' paths for each item, rank item based on average score, pick top k items.
    """
    item_paths = {}
    average_item_score = {}

    path_scores = sorted(zip(X_test, y_pred), key=lambda x: x[1], reverse=get_best)
    for path, score in path_scores:

        ending_item = path[3][0] # The last item before END RELATION

        if ending_item not in item_paths:
            item_paths[ending_item] = []
            average_item_score[ending_item] = []

        if len(item_paths[ending_item]) < max_pooling_size:
            item_paths[ending_item].append((path, score))
            average_item_score[ending_item].append(score)

    # Calculate average
    for item in average_item_score:
        average_item_score[item] = sum(average_item_score[item]) / len(average_item_score[item])

    sorted_average_score = sorted(average_item_score.items(), key=lambda kv: kv[1], reverse=get_best)
    choosen_items = {key for key, v in sorted_average_score[:k]}

    choosen_paths = []
    for item_id in choosen_items:
        choosen_paths += item_paths[item_id]

    return choosen_paths, choosen_items

# %%
def get_suggestion(user_id, k=10, max_pooling_size=-1):
    user_paths = generate_all_path_from_user(user_id, max_seed_num=MAX_SEED_NUM, max_seed_ratio=0.3)
    X_test, y_true = reformat_user_path(user_paths)
    y_pred = model.predict(X_test, batch_size=2048, verbose=1)
    
    top_paths, top_choosen_items = _get_k_prediction(X_test, y_pred, k=10, get_best=True, max_pooling_size=max_pooling_size)
    worst_path, worst_choosen_items = _get_k_prediction(X_test, y_pred, k=10, get_best=False, max_pooling_size=max_pooling_size)
    
    return top_paths, top_choosen_items, worst_path, worst_choosen_items

# %%
def get_top_truth(user_id):
    return set(kg_path[user_id][GIVEN_RATING_RELATION])

# %%
def check_precision(pred, truth, k=10):    
    
    # Make sure same type
    pred = {str(x) for x in pred}
    truth = {str(x) for x in truth}

    intersect = pred.intersection(truth)
    
    len_intersect = len(intersect)
    len_truth = len(truth) if 0 < len(truth) <= k else k
    
    return intersect, len_intersect / len_truth

# %% [markdown]
# ## >> Reasoning

# %%
file_ratings_re = open("../data/ratings_re.csv").readlines()
file_triples_idx = open("../data/triples_idx.txt").readlines()

file_moviesIdx = open("../data/moviesIdx.txt").readlines() 
file_types = open("../data/types.txt").readlines() 
file_entities = open("../data/entities.txt").readlines()
file_relations = open("../data/relations.txt").readlines()

# %%
# create entity id -> name mapping
entity_id_to_name = {}
for line in file_moviesIdx:
    movie_title, entity_id = line.strip().split()
    entity_id_to_name[entity_id] = movie_title
    
for line in file_entities:
    entity_name, entity_id = line.strip().split()
    entity_id_to_name[entity_id] = entity_name

# %%
# Create relation id to name mapping
relation_id_to_name = {}
for line in file_relations:
    relation_name, relation_id = line.strip().split()
    relation_id = int(relation_id)
    relation_id += 200000
    
    # last 2 relation : spouse and relative has no inverse
    if relation_id < 200023:
        relation_id_to_name[str(relation_id + 1)] = relation_name + "_inverse"
    
    relation_id_to_name[str(relation_id)] = relation_name
    
relation_id_to_name['200030'] = "END"

# %%
def get_entity_name(entity_id):
    
    if entity_id in entity_id_to_name:
        return entity_id_to_name[entity_id]
    elif entity_id in relation_id_to_name:
        return relation_id_to_name[entity_id]
    else:
        return "user_{}".format(entity_id)

# %%
def get_reasoning_paths(paths, truth_items=None):
    reasoning_paths = []
    for i in range(0, len(paths)):
        user_path = paths[i]
        user_truth = truth_items[i]

        for path in user_path: 

            score = path[1]
            reason_path = [str(score)]

            for sequence in path[0]:
                entity, _, relation = sequence
                e = get_entity_name(str(entity))
                r = get_entity_name(str(relation))

                reason_path.append(e)
                reason_path.append(r)
                
                if str(relation) == END_RELATION:
                    watched = 'watched' if str(entity) in user_truth else "nope"
                    reason_path.append(watched)

            reason = " -> ".join(reason_path)
            reasoning_paths.append(reason)
    return reasoning_paths

# %%
import pandas as pd

def get_reasoning_paths_df(paths, truth_items=None):
    reasoning_paths = []
    for i in range(0, len(paths)):
        user_path = paths[i]
        user_truth = truth_items[i]

        for path in user_path: 

            score = path[1]
            reason_path = [str(score)]

            for sequence in path[0]:
                entity, _, relation = sequence
                e = get_entity_name(str(entity))
                r = get_entity_name(str(relation))

                reason_path.append(e)
                reason_path.append(r)
                
                if str(relation) == END_RELATION:
                    watched = 'watched' if str(entity) in user_truth else "nope"
                    reason_path.append(watched)

            reasoning_paths.append(reason_path)
    return pd.DataFrame(reasoning_paths)

# %% [markdown]
#     df = None
#     for i in range(0, 10):
#         _df = get_reasoning_paths_df([top_paths[i]], [truth_items[i]])
#         if df is None:
#             df = _df
#         else:
#             df = pd.concat([df, _df], axis=0)
#
#     df.to_csv("KPRN_pooling5.csv")

# %%
def compare_prediction_truth(predictions, truths):
    
    predictions = [get_entity_name(str(p)) for p in predictions]
    truths = [get_entity_name(str(t)) for t in truths]
    
    print("Predictions : ")
    for p in sorted(predictions):
        is_watched = "watched" if str(p) in truths else "nope"
        print("{} > {}".format(p, is_watched))
    
    print("\n")
    print("Truth : ")
    for t in sorted(truths):
        print(t)

# %% [markdown]
# ## >> Run evaluation

# %%
import numpy as np

k = 10
n = 10

sample_user = np.random.randint(500001, 630000, n)
sample_user = [str(x) for x in sample_user]

top_paths = []
top_items = []
worst_paths = []
worst_items = []

truth_items = []

n_paths = []
intersects = []
scores = []

all_intersect = None
all_union = None

for user in tqdm(sample_user):
    top_suggested_path, top_suggested_items, worst_suggested_path, worst_suggested_items = get_suggestion(user, k=k, max_pooling_size=5)
    top_truth_items = get_top_truth(user)
    
    intersect, score = check_precision(top_suggested_items, top_truth_items)
    
    top_paths.append(top_suggested_path)
    top_items.append(top_suggested_items)
    
    worst_paths.append(worst_suggested_path)
    worst_items.append(worst_suggested_items)
    
    intersects.append(intersect)
    truth_items.append(top_truth_items)
    
    n_paths.append(len(top_suggested_path))
    scores.append(score)
    
    if all_intersect is None:
        all_intersect = top_suggested_items
    else:
        all_intersect = all_intersect.intersection(top_suggested_items)
   
    if all_union is None:
        all_union = top_suggested_items
    else:
        all_union = all_union.union(top_suggested_items)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 88550/88550 [==============================] - 1s 12us/step
#  10%|█         | 1/10 [00:20<03:03, 20.35s/it]
# 104415/104415 [==============================] - 0s 3us/step
#  20%|██        | 2/10 [01:00<03:30, 26.30s/it]
# 91186/91186 [==============================] - 0s 3us/step
#  30%|███       | 3/10 [02:07<04:28, 38.39s/it]
# 80068/80068 [==============================] - 0s 3us/step
#  40%|████      | 4/10 [02:31<03:24, 34.12s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-d33b7ba643f2> in <module>
#      33
#      34 for user in tqdm(sample_user):
# ---> 35     top_suggested_path, top_suggested_items, worst_suggested_path, worst_suggested_items = get_suggestion(user, k=k, max_pooling_size=5)
#      36     top_truth_items = get_top_truth(user)
#      37
#
# <ipython-input-21-955bb1d911d8> in get_suggestion(user_id, k, max_pooling_size)
#       1 def get_suggestion(user_id, k=10, max_pooling_size=-1):
# ----> 2     user_paths = generate_all_path_from_user(user_id, max_seed_num=MAX_SEED_NUM, max_seed_ratio=0.3)
#       3     X_test, y_true = reformat_user_path(user_paths)
#       4     y_pred = model.predict(X_test, batch_size=2048, verbose=1)
#       5
#
# <ipython-input-16-ecc1918713ff> in generate_all_path_from_user(user_id, max_seed_num, max_seed_ratio)
#      33
#      34     for i in range(0, n_seed):
# ---> 35         threads[i].join()
#      36
#      37     user_paths = ["{} {} {}".format(user_id, "200027", x) for x in user_paths]
#
# /usr/lib/python3.5/threading.py in join(self, timeout)
#    1052
#    1053         if timeout is None:
# -> 1054             self._wait_for_tstate_lock()
#    1055         else:
#    1056             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.5/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1068         if lock is None:  # already determined that the C code is done
#    1069             assert self._is_stopped
# -> 1070         elif lock.acquire(block, timeout):
#    1071             lock.release()
#    1072             self._stop()
#
# KeyboardInterrupt:

# %%
print("Prec@k score:", np.average(scores))
# print("top_suggested_items:", top_suggested_items)
# print("truth_items:", truth_items)

print("\nintersect")
print(all_intersect, len(all_intersect))
print("\nunion")
print(all_union, len(all_union))
print("\ndistinct rate")
print((len(all_union)) / (n*k))
# Out:
# Prec@k score: 0.18666666666666668
#
# intersect
# {11536, 10659} 2
#
# union
# {5058, 8962, 14025, 3401, 4687, 11536, 911, 1168, 12436, 10388, 1557, 2073, 11677, 5277, 5278, 5279, 5409, 546, 10659, 676, 8672, 11494, 616, 10796, 11502, 1392, 6834, 5619, 9846, 4791, 5629} 31
#
# distinct rate
# 0.31

# %%
# sample_user_idx = 0
# get_reasoning_paths([top_paths[sample_user_idx]], [truth_items[sample_user_idx]])
# compare_prediction_truth(top_items[sample_user_idx], truth_items[sample_user_idx])
# Out:
# Predictions :
# http://dbpedia.org/resource/Dances_with_Wolves > nope
# http://dbpedia.org/resource/Fargo_(film) > nope
# http://dbpedia.org/resource/Forrest_Gump > nope
# http://dbpedia.org/resource/Good_Will_Hunting > nope
# http://dbpedia.org/resource/Goodfellas > nope
# http://dbpedia.org/resource/Monty_Python_and_the_Holy_Grail > nope
# http://dbpedia.org/resource/Pulp_Fiction > nope
# http://dbpedia.org/resource/Raiders_of_the_Lost_Ark > nope
# http://dbpedia.org/resource/Schindler's_List > nope
# http://dbpedia.org/resource/Toy_Story > nope
#
#
# Truth :
# http://dbpedia.org/resource/Dazed_and_Confused_(film)
# http://dbpedia.org/resource/Deliverance_(1919_film)
# http://dbpedia.org/resource/Dumbo
# http://dbpedia.org/resource/Fast_Times_at_Ridgemont_High
# http://dbpedia.org/resource/Lost_in_Translation_(film)
# http://dbpedia.org/resource/Mean_Creek

# %%
sample_user = ['520169',
 '566966',
 '582374',
 '504296',
 '510204',
 '623623',
 '615870',
 '628970',
 '583750',
 '597239']

autorec_result = [[5058, 10659, 7304, 2073, 13122, 14025, 11536, 6825, 1321, 911],
[5058, 10659, 7304, 2073, 13122, 14025, 11536, 1321, 6825, 911],
[13712, 8497, 13405, 10659, 5058, 7304, 1839, 2073, 13310, 13122],
[5058, 10659, 7304, 2073, 13122, 14025, 11536, 6825, 1321, 10796],
[5058, 10659, 7304, 2073, 13122, 14025, 11536, 1321, 6825, 911],
[5058, 10659, 7304, 2073, 13122, 14025, 11536, 6825, 1321, 911],
[5058, 10659, 7304, 2073, 13122, 14025, 11536, 1321, 6825, 911],
[5058, 10659, 7304, 2073, 13122, 14025, 11536, 6825, 1321, 911],
[5058, 10659, 7304, 2073, 13122, 14025, 11536, 6825, 1321, 10796],
[5058, 10659, 7304, 2073, 13122, 14025, 11536, 1321, 6825, 911]]
        
top_truth = [get_top_truth(x) for x in sample_user]

for i in range(0, len(autorec_result)):
    line = autorec_result[i]
    for entity in line:
        entity_name = get_entity_name(str(entity))
        watched = "watched" if str(entity) in top_truth[i] else "nope"
            
        print("{} > {}".format(entity_name, watched))
    print()
# Out:
# http://dbpedia.org/resource/Forrest_Gump > nope
# http://dbpedia.org/resource/Pulp_Fiction > nope
# http://dbpedia.org/resource/Jurassic_Park_(film) > nope
# http://dbpedia.org/resource/Braveheart_(1925_film) > nope
# http://dbpedia.org/resource/Terminator_2:_Judgment_Day > nope
# http://dbpedia.org/resource/Toy_Story > nope
# http://dbpedia.org/resource/Schindler's_List > nope
# http://dbpedia.org/resource/Independence_Day_(2000_film) > nope
# http://dbpedia.org/resource/Batman_(1989_film) > nope
# http://dbpedia.org/resource/Apollo_13_(film) > nope
#
# http://dbpedia.org/resource/Forrest_Gump > nope
# http://dbpedia.org/resource/Pulp_Fiction > nope
# http://dbpedia.org/resource/Jurassic_Park_(film) > nope
# http://dbpedia.org/resource/Braveheart_(1925_film) > nope
# http://dbpedia.org/resource/Terminator_2:_Judgment_Day > nope
# http://dbpedia.org/resource/Toy_Story > watched
# http://dbpedia.org/resource/Schindler's_List > nope
# http://dbpedia.org/resource/Batman_(1989_film) > nope
# http://dbpedia.org/resource/Independence_Day_(2000_film) > nope
# http://dbpedia.org/resource/Apollo_13_(film) > nope
#
# http://dbpedia.org/resource/Thirst_(1960_film) > nope
# http://dbpedia.org/resource/Manufacturing_Dissent > nope
# http://dbpedia.org/resource/The_Killers_(1964_film) > nope
# http://dbpedia.org/resource/Pulp_Fiction > nope
# http://dbpedia.org/resource/Forrest_Gump > nope
# http://dbpedia.org/resource/Jurassic_Park_(film) > nope
# http://dbpedia.org/resource/Blood_Money_(2012_film) > nope
# http://dbpedia.org/resource/Braveheart_(1925_film) > watched
# http://dbpedia.org/resource/The_Fifth_Season_(film) > nope
# http://dbpedia.org/resource/Terminator_2:_Judgment_Day > nope
#
# http://dbpedia.org/resource/Forrest_Gump > nope
# http://dbpedia.org/resource/Pulp_Fiction > nope
# http://dbpedia.org/resource/Jurassic_Park_(film) > nope
# http://dbpedia.org/resource/Braveheart_(1925_film) > nope
# http://dbpedia.org/resource/Terminator_2:_Judgment_Day > nope
# http://dbpedia.org/resource/Toy_Story > nope
# http://dbpedia.org/resource/Schindler's_List > nope
# http://dbpedia.org/resource/Independence_Day_(2000_film) > nope
# http://dbpedia.org/resource/Batman_(1989_film) > nope
# http://dbpedia.org/resource/Raiders_of_the_Lost_Ark > nope
#
# http://dbpedia.org/resource/Forrest_Gump > watched
# http://dbpedia.org/resource/Pulp_Fiction > nope
# http://dbpedia.org/resource/Jurassic_Park_(film) > nope
# http://dbpedia.org/resource/Braveheart_(1925_film) > watched
# http://dbpedia.org/resource/Terminator_2:_Judgment_Day > nope
# http://dbpedia.org/resource/Toy_Story > nope
# http://dbpedia.org/resource/Schindler's_List > nope
# http://dbpedia.org/resource/Batman_(1989_film) > nope
# http://dbpedia.org/resource/Independence_Day_(2000_film) > nope
# http://dbpedia.org/resource/Apollo_13_(film) > nope
#
# http://dbpedia.org/resource/Forrest_Gump > watched
# http://dbpedia.org/resource/Pulp_Fiction > nope
# http://dbpedia.org/resource/Jurassic_Park_(film) > watched
# http://dbpedia.org/resource/Braveheart_(1925_film) > watched
# http://dbpedia.org/resource/Terminator_2:_Judgment_Day > nope
# http://dbpedia.org/resource/Toy_Story > watched
# http://dbpedia.org/resource/Schindler's_List > nope
# http://dbpedia.org/resource/Independence_Day_(2000_film) > nope
# http://dbpedia.org/resource/Batman_(1989_film) > nope
# http://dbpedia.org/resource/Apollo_13_(film) > watched
#
# http://dbpedia.org/resource/Forrest_Gump > watched
# http://dbpedia.org/resource/Pulp_Fiction > watched
# http://dbpedia.org/resource/Jurassic_Park_(film) > watched
# http://dbpedia.org/resource/Braveheart_(1925_film) > watched
# http://dbpedia.org/resource/Terminator_2:_Judgment_Day > watched
# http://dbpedia.org/resource/Toy_Story > nope
# http://dbpedia.org/resource/Schindler's_List > watched
# http://dbpedia.org/resource/Batman_(1989_film) > watched
# http://dbpedia.org/resource/Independence_Day_(2000_film) > nope
# http://dbpedia.org/resource/Apollo_13_(film) > watched
#
# http://dbpedia.org/resource/Forrest_Gump > watched
# http://dbpedia.org/resource/Pulp_Fiction > watched
# http://dbpedia.org/resource/Jurassic_Park_(film) > watched
# http://dbpedia.org/resource/Braveheart_(1925_film) > nope
# http://dbpedia.org/resource/Terminator_2:_Judgment_Day > watched
# http://dbpedia.org/resource/Toy_Story > nope
# http://dbpedia.org/resource/Schindler's_List > nope
# http://dbpedia.org/resource/Independence_Day_(2000_film) > nope
# http://dbpedia.org/resource/Batman_(1989_film) > nope
# http://dbpedia.org/resource/Apollo_13_(film) > nope
#
# http://dbpedia.org/resource/Forrest_Gump > watched
# http://dbpedia.org/resource/Pulp_Fiction > nope
# http://dbpedia.org/resource/Jurassic_Park_(film) > nope
# http://dbpedia.org/resource/Braveheart_(1925_film) > nope
# http://dbpedia.org/resource/Terminator_2:_Judgment_Day > nope
# http://dbpedia.org/resource/Toy_Story > nope
# http://dbpedia.org/resource/Schindler's_List > nope
# http://dbpedia.org/resource/Independence_Day_(2000_film) > nope
# http://dbpedia.org/resource/Batman_(1989_film) > nope
# http://dbpedia.org/resource/Raiders_of_the_Lost_Ark > nope
#
# http://dbpedia.org/resource/Forrest_Gump > nope
# http://dbpedia.org/resource/Pulp_Fiction > watched
# http://dbpedia.org/resource/Jurassic_Park_(film) > watched
# http://dbpedia.org/resource/Braveheart_(1925_film) > nope
# http://dbpedia.org/resource/Terminator_2:_Judgment_Day > nope
# http://dbpedia.org/resource/Toy_Story > nope
# http://dbpedia.org/resource/Schindler's_List > watched
# http://dbpedia.org/resource/Batman_(1989_film) > nope
# http://dbpedia.org/resource/Independence_Day_(2000_film) > watched
# http://dbpedia.org/resource/Apollo_13_(film) > watched

# %% [markdown]
# ## >> Custom test

# %%
def run_filtered_path_thread(thread_id, thread_items, result, keep_list=None):
    print("Thread {} : start".format(thread_id))
    for item_id in (thread_items):
        _result = generate_path_from_entity_to_all_others(item_id, keep_relation_ratio=1, max_relation_num=99, max_entity_per_relation=99999)
        _filtered = [x for x in _result if x.split()[-1] in keep_list]
        result += _filtered
    print("Thread {} : exit".format(thread_id))
    
def generate_filtered_path_from_user(user_id, n_truth_tail=10, n_false_tail=10):
    
    user_interacted_items = []
    for relation in kg_path[user_id]:
        user_interacted_items += kg_path[user_id][relation]
    user_interacted_items = sorted(set(user_interacted_items))
    
    print("user_interacted_items:", user_interacted_items)
    
    # Random select truth items
    np.random.shuffle(user_interacted_items)
    choosen_truth = user_interacted_items[:n_truth_tail]
    
    # Random select false items
    choosen_false = np.random.randint(0, 15440, size=n_false_tail+len(user_interacted_items)).astype("str")
    choosen_false = list(set(choosen_false) - set(user_interacted_items))
    choosen_false = choosen_false[:n_false_tail]
    
    keep_list = choosen_truth + choosen_false
    
    # ====== Threading ======
    user_paths = []
    threads = []

    for i in range(0, len(user_interacted_items)):        
        # Split item id equally
        thread_items = [user_interacted_items[i]]
        thread = threading.Thread(target=run_filtered_path_thread, args=(i, thread_items, user_paths, keep_list))    
        thread.start()
        threads.append(thread)
    
    print("n threads:", len(threads))
    
    for thread in threads:
        thread.join()
    
    user_paths = ["{} {} {}".format(user_id, "200027", x) for x in user_paths]
    return user_paths, choosen_truth, choosen_false

# %%
def get_custom_suggestion(user_id, k=10, n_truth_tail=10, n_false_tail=10, max_pooling_size=-1):
    user_paths, choosen_truth, choosen_false = generate_filtered_path_from_user(user_id, n_truth_tail=n_truth_tail, n_false_tail=n_false_tail)
    X_test, y_true = reformat_user_path(user_paths)
    y_pred = model.predict(X_test, batch_size=2048, verbose=1)
    
    top_paths, top_choosen_items = _get_k_prediction(X_test, y_pred, k=10, get_best=True, max_pooling_size=max_pooling_size)
    worst_path, worst_choosen_items = _get_k_prediction(X_test, y_pred, k=10, get_best=False, max_pooling_size=max_pooling_size)
    
    return top_paths, top_choosen_items, worst_path, worst_choosen_items, choosen_truth, choosen_false

# %%
import numpy as np

k = 10
n = 1
n_truth_tail=10
n_false_tail=10

sample_user = np.random.randint(500001, 630000, n)
sample_user = [str(x) for x in sample_user]

top_paths = []
worst_paths = []
truth_items = []

n_paths = []
intersects = []
scores = []

all_intersect = None
all_union = None

for user in tqdm(sample_user):
    top_suggested_path, top_suggested_items, worst_suggested_path, worst_suggested_items, choosen_truth, choosen_false = get_custom_suggestion(user, k, n_truth_tail, n_false_tail, max_pooling_size=-1)
    top_truth_items = get_top_truth(user)
    intersect, score = check_precision(top_suggested_items, top_truth_items)
    
    top_paths.append(top_suggested_path)
    worst_paths.append(worst_suggested_path)
    intersects.append(intersect)
    truth_items.append(top_truth_items)
    
    n_paths.append(len(top_suggested_path))
    scores.append(score)
    
    if all_intersect is None:
        all_intersect = top_suggested_items
    else:
        all_intersect = all_intersect.intersection(top_suggested_items)
   
    if all_union is None:
        all_union = top_suggested_items
    else:
        all_union = all_union.union(top_suggested_items)
        
print("Prec@k score:", np.average(scores))
print("\nintersect")
print(all_intersect, len(all_intersect))
print("\nunion")
print(all_union, len(all_union))
print("\ndistinct rate")
print((len(all_union)) / (n*k))
print("choosen_truth", choosen_truth) 
print("choosen_false", choosen_false)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# user_interacted_items: ['10187', '10201', '10306', '10390', '10422', '10515', '10545', '10546', '10659', '10796', '1085', '10878', '10880', '11006', '11145', '11146', '11177', '11243', '11251', '11361', '11363', '11494', '11507', '11677', '1168', '11690', '11797', '11964', '11979', '12072', '12121', '12153', '12196', '12250', '12339', '12342', '12348', '12372', '12404', '12451', '12452', '12455', '12457', '12458', '12459', '12461', '12462', '12475', '12489', '12626', '12677', '12889', '1300', '13043', '13115', '13122', '13126', '13168', '1320', '1324', '136', '13654', '13770', '13837', '13872', '13881', '13891', '13974', '1402', '14162', '14516', '14618', '1483', '14868', '14920', '15073', '15075', '15154', '15294', '15333', '1599', '1772', '1774', '1782', '2474', '2506', '2514', '26', '2632', '2767', '2897', '2903', '2959', '3071', '3137', '3264', '327', '3302', '3401', '3414', '3428', '3436', '3523', '3701', '3732', '3785', '3815', '3855', '3922', '394', '3987', '4080', '4113', '4195', '4215', '4378', '4411', '4630', '4685', '4700', '4771', '4862', '4934', '5033', '5161', '5193', '5209', '5325', '533', '534', '5409', '5425', '5439', '5441', '546', '5515', '5582', '5601', '5629', '5692', '5736', '5738', '5803', '6018', '6021', '6199', '652', '6585', '6625', '6759', '6791', '6796', '6834', '6835', '6881', '6930', '7083', '709', '7135', '7304', '7366', '7420', '7516', '7526', '7550', '7556', '7622', '7631', '7665', '7772', '7806', '7867', '7868', '7869', '7927', '8413', '8688', '8736', '8860', '8878', '8962', '9002', '909', '9139', '9185', '9205', '9364', '9620', '9661', '9662', '9714', '981', '996', '9994']
# Thread 0 : start
# ['327']Thread 1 : start
# ['13168']
#
# Thread 2 : start
# ['3436']
# Thread 3 : start
# ['12372']
# Thread 4 : start
# ['7526']
# Thread 5 : start
# ['3302']
# Thread 6 : start
# ['3401']
# Thread 7 : start
# ['11363']
# Thread 8 : start
# ['12626']
# Thread 9 : start
# ['12072']
# Thread 10 : start
# ['5515']
# Thread 11 : start
# ['6881']
# Thread 12 : start
# ['13122']
# Thread 13 : start
# ['11243']
# Thread 14 : start
# ['8736']Thread 15 : start
#
# ['3523']
# Thread 16 : start
# ['5441']
# Thread 17 : start
# ['11690']
# Thread 18 : start
# ['12339']
# Thread 19 : startThread 20 : start
# ['12462']
# Thread 21 : start
# ['13974']
#
# ['15333']
# Thread 22 : start
# ['3855']
# Thread 23 : start
# ['7556']Thread 24 : start
#
# ['12196']
# Thread 25 : start
# ['6199']
# Thread 26 : start
# ['14618']Thread 27 : start
# ['3264']
#
# Thread 28 : startThread 29 : start
# ['7868']
# Thread 30 : start
# ['15294']
# ['7516']
#
# Thread 31 : start
# ['7869']
# Thread 32 : start
# ['6625']
# Thread 33 : start
# ['5325']Thread 34 : start
# ['4411']
#
# Thread 35 : start
# Thread 36 : start
# ['7772']Thread 37 : start
# ['6021']
#
# Thread 38 : start
# ['8860']
# ['5803']
# Thread 39 : start
# ['5439']
# Thread 40 : start
# ['11361']
# Thread 41 : start
# ['9661']
# Thread 42 : start
# ['11964']
# Thread 43 : start
# ['6018']
# Thread 44 : start
# ['9364']
# Thread 45 : start
# ['10201']
# Thread 46 : startThread 47 : start
# ['1402']
#
# ['7867']
# Thread 48 : start
# ['13891']
# Thread 49 : start
# ['9139']
# Thread 50 : start
# ['1320']
# Thread 51 : start
# ['909']
# Thread 52 : start
# ['5601']
# Thread 53 : start
# ['7631']Thread 54 : start
# ['3414']
#
# Thread 55 : start
# ['6759']
# Thread 56 : start
# ['10880']
# Thread 57 : start
# ['981']
# Thread 58 : start
# ['11251']
# Thread 59 : startThread 60 : start
# Thread 61 : start
# ['3815']
# Thread 62 : start
# ['4378']
#
# Thread 63 : start
# ['8413']
# ['6796']Thread 64 : start['652']
#
# ['4080']
#
# Thread 65 : start
# ['10306']
# Thread 66 : start
# ['4700']
# Thread 67 : start
# ['136']
# Thread 68 : start
# ['7366']
# Thread 69 : start
# Thread 70 : start
# ['2959']
# ['13043']
# Thread 71 : start
# ['10796']
# Thread 72 : start
# ['3701']
# Thread 73 : start
# ['8962']
# Thread 74 : start
# ['5738']
# Thread 75 : start
# ['9002']
# Thread 76 : startThread 77 : start
# ['10422']
# Thread 78 : start
# ['13654']
# Thread 79 : start
# ['10187']
# Thread 80 : start
# ['12457']
# Thread 81 : start
# ['9714']
# Thread 82 : start
# ['1774']
# Thread 83 : start
# ['7304']
#
# ['4771']
# Thread 84 : startThread 85 : start
# ['14162']
#
# ['12475']
# Thread 86 : start
# ['4113']
# Thread 87 : start
# Thread 88 : startThread 89 : start
# ['3071']
# ['5161']
#
# Thread 90 : start
# Thread 91 : start
# ['11145']
# Thread 92 : start
# ['6834']['12348']
# Thread 93 : start
# ['6930']
#
# Thread 94 : start
# ['3137']
# Thread 95 : start
# ['4862']
# ['12455']
# Thread 96 : start
# ['709']
# Thread 97 : start
# ['4685']Thread 98 : start
# ['3785']
# Thread 99 : start
# ['5736']
# Thread 100 : start
# ['14920']
#
# Thread 101 : start
# ['12461']
# Thread 102 : start
# ['13126']
# Thread 103 : start
# ['1300']
# Thread 104 : start
# ['12451']
# Thread 105 : start
# ['1772']
# Thread 106 : startThread 107 : start
# ['11006']
#
# Thread 108 : start
# ['7927']
# ['11797']
# Thread 109 : start
# ['13770']
# Thread 110 : start
# ['4934']
# Thread 111 : start
# ['546']
# Thread 112 : start
# ['13881']
# Thread 113 : start
# ['10659']
# Thread 114 : start
# Thread 115 : start
# ['12458']
# Thread 116 : start
# ['12250']
# ['9205']
# Thread 117 : start
# ['15075']
# Thread 118 : start
# ['7665']
# Thread 119 : start
# ['11507']
# Thread 120 : start
# ['13872']
# Thread 121 : startThread 122 : start
# ['8878']
# Thread 123 : start
# ['7806']
#
# Thread 124 : start['10878']
#
# ['12121']Thread 125 : start
# ['996']
#
# Thread 126 : start
# ['12404']
# Thread 127 : start
# ['1168']
# Thread 128 : start
# ['2632']
# Thread 129 : start
# ['4215']
# Thread 130 : startThread 131 : start
# ['10390']
#
# Thread 132 : start
# ['6835']
# ['12342']
# Thread 133 : start
# ['4195']
# Thread 134 : start
# ['7622']
# Thread 135 : start
# ['7420']
# Thread 136 : start
# ['11146']
# Thread 137 : startThread 138 : start
# ['1782']
#
# ['6585']
# Thread 139 : startThread 140 : start
# Thread 141 : start
# ['1599']
#
# ['9185']
# ['7083']Thread 142 : start
#
# Thread 143 : start
# ['2474']
# ['2903']
# Thread 144 : startThread 145 : start
# ['534']
#
# Thread 146 : start
# ['5629']
# Thread 147 : start
# ['6791']
# Thread 148 : start
# ['12459']Thread 149 : start
# ['14516']
#
# Thread 150 : start['11494']
# ['2767']
#
# Thread 151 : start
# ['8688']
# Thread 152 : startThread 153 : start
# ['7135']
# Thread 154 : start
# ['2897']
#
# ['4630']
# Thread 155 : startThread 156 : start
# ['10546']
#
# ['5692']
# Thread 157 : startThread 158 : start
# ['2506']
#
# ['5582']
# Thread 159 : start
# ['394']
# Thread 160 : start
# Thread 161 : startThread 162 : start
# ['1483']Thread 163 : start
# ['9620']
# ['12153']
# ['5425']
#
# Thread 164 : startThread 42 : len 500 set 500
# Thread 42 : exit
#
# Thread 165 : start
# ['11979']
#
# ['5209']
# Thread 166 : start
# ['7550']
# Thread 167 : start
# ['5193']
# Thread 168 : start
# ['10515']
# Thread 169 : start
# ['10545']
# Thread 170 : start
# ['3987']
# Thread 171 : start
# ['3922']
# Thread 55 : len 278 set 278
# Thread 55 : exit
# Thread 172 : start
# ['12677']
# Thread 173 : start
# ['9994']Thread 174 : start
# ['12889']
#
# Thread 175 : start
# Thread 176 : start
# ['1324']
# ['15073']
# Thread 177 : start
# ['12489']
# Thread 178 : start
# Thread 179 : start
# ['26']
# ['13115']
# Thread 180 : start
# ['3732']Thread 181 : start
# ['1085']
# Thread 11 : len 1189 set 1189
# Thread 1 : len 915 set 915Thread 182 : start
# ['3428']
#
#
# Thread 11 : exit
# Thread 183 : startThread 40 : len 696 set 696
# ['11177']
# Thread 184 : start
# ['2514']
#
# Thread 40 : exit
# Thread 1 : exitThread 185 : start
# Thread 186 : start
# ['9662']
# Thread 187 : start
# ['5409']
# ['11677']Thread 188 : start
# ['12452']
# Thread 189 : start
#
# ['5033']
#
# Thread 190 : startThread 191 : start
# ['14868']
#
# ['15154']
# Thread 192 : start
# ['533']
# Thread 193 : start
# ['13837']
# n threads: 194
# Thread 32 : len 523 set 523
# Thread 32 : exit
# Thread 28 : len 1184 set 1184
# Thread 28 : exit
# Thread 126 : len 154 set 154Thread 68 : len 459 set 459
# Thread 126 : exit
#
# Thread 68 : exit
# Thread 135 : len 76 set 76
# Thread 135 : exit
# Thread 13 : len 1651 set 1651Thread 49 : len 1700 set 1700
# Thread 13 : exit
#
# Thread 49 : exit
# Thread 108 : len 668 set 668
# Thread 108 : exit
# Thread 47 : len 1978 set 1978
# Thread 47 : exit
# Thread 63 : len 2621 set 2621
# Thread 63 : exit
# Thread 50 : len 1294 set 1294
# Thread 50 : exit
# Thread 62 : len 1299 set 1299
# Thread 62 : exit
# Thread 19 : len 2376 set 2376
# Thread 19 : exit
# Thread 91 : len 2315 set 2315
# Thread 91 : exit
# Thread 0 : len 2449 set 2449
# Thread 0 : exitThread 67 : len 2340 set 2340
# Thread 67 : exit
#
# Thread 124 : len 1610 set 1610
# Thread 124 : exit
# Thread 116 : len 1688 set 1688
# Thread 116 : exit
# Thread 140 : len 2005 set 2005
# Thread 140 : exit
# Thread 23 : len 3318 set 3318Thread 182 : len 1033 set 1033
# Thread 182 : exit
#
# Thread 23 : exit
# Thread 137 : len 1584 set 1584
# Thread 14 : len 3128 set 3128
# Thread 14 : exitThread 137 : exit
#
# Thread 166 : len 1139 set 1139
# Thread 166 : exit
# Thread 134 : len 1718 set 1718
# Thread 168 : len 1516 set 1516Thread 134 : exit
#
# Thread 168 : exit
# Thread 123 : len 2381 set 2381Thread 189 : len 1105 set 1105
# Thread 123 : exit
# Thread 189 : exit
#
# Thread 106 : len 2400 set 2400
# Thread 106 : exit
# Thread 167 : len 1815 set 1815
# Thread 167 : exitThread 178 : len 1463 set 1463
#
# Thread 178 : exit
# Thread 75 : len 2652 set 2652
# Thread 75 : exit
# Thread 155 : len 2341 set 2341
# Thread 155 : exit
# Thread 101 : len 2447 set 2447
# Thread 101 : exit
# Thread 18 : len 4251 set 4251
# Thread 36 : len 3763 set 3763
# Thread 36 : exit
# Thread 18 : exit
# Thread 138 : len 2721 set 2721
# Thread 138 : exit
# Thread 110 : len 3488 set 3488
# Thread 110 : exit
# Thread 122 : len 3259 set 3259
# Thread 122 : exit
# Thread 34 : len 3599 set 3599
# Thread 34 : exit
# Thread 15 : len 4692 set 4692
# Thread 15 : exit
# Thread 97 : len 3382 set 3382
# Thread 97 : exit
# Thread 31 : len 4684 set 4684
# Thread 31 : exit
# Thread 5 : len 3352 set 3352
# Thread 5 : exit
# Thread 152 : len 3352 set 3352
# Thread 152 : exit
# Thread 89 : len 4146 set 4146Thread 77 : len 4334 set 4334
# Thread 77 : exit
#
# Thread 89 : exit
# Thread 159 : len 3256 set 3256Thread 4 : len 4471 set 4471Thread 88 : len 4537 set 4537
# Thread 159 : exit
#
#
# Thread 4 : exit
# Thread 88 : exit
# Thread 174 : len 3130 set 3130
# Thread 174 : exit
# Thread 109 : len 4052 set 4052
# Thread 109 : exit
# Thread 102 : len 5119 set 5119
# Thread 102 : exit
# Thread 56 : len 4965 set 4965
# Thread 56 : exit
# Thread 87 : len 7311 set 7311
# Thread 87 : exit
# Thread 128 : len 5077 set 5077Thread 95 : len 6075 set 6075
# Thread 95 : exit
#
# Thread 128 : exit
# Thread 45 : len 5181 set 5181
# Thread 45 : exit
# Thread 164 : len 3404 set 3404Thread 8 : len 5287 set 5287
# Thread 8 : exit
#
# Thread 164 : exit
# Thread 3 : len 6530 set 6530
# Thread 3 : exit
# Thread 22 : len 6815 set 6815
# Thread 22 : exit
# Thread 44 : len 5530 set 5530
# Thread 44 : exit
# Thread 70 : len 7455 set 7455
# Thread 70 : exit
# Thread 112 : len 5845 set 5845
# Thread 30 : len 6865 set 6865
# Thread 30 : exit
# Thread 112 : exit
# Thread 66 : len 6156 set 6156
# Thread 66 : exitThread 147 : len 4069 set 4069
# Thread 147 : exit
#
# Thread 20 : len 6487 set 6487Thread 90 : len 4938 set 4938
# Thread 90 : exit
#
# Thread 20 : exit
# Thread 115 : len 5721 set 5721
# Thread 115 : exit
# Thread 188 : len 4189 set 4189Thread 93 : len 5012 set 5012
# Thread 188 : exit
#
# Thread 93 : exit
# Thread 139 : len 6592 set 6592
# Thread 139 : exit
# Thread 39 : len 5280 set 5280
# Thread 39 : exit
# Thread 192 : len 4192 set 4192
# Thread 192 : exit
# Thread 98 : len 5823 set 5823
# Thread 98 : exit
# Thread 170 : len 5963 set 5963
# Thread 170 : exit
# Thread 86 : len 5837 set 5837
# Thread 86 : exit
# Thread 103 : len 7214 set 7214
# Thread 103 : exit
# Thread 156 : len 5027 set 5027
# Thread 156 : exit
# Thread 72 : len 7009 set 7009
# Thread 72 : exit
# Thread 41 : len 5483 set 5483
# Thread 41 : exit
# Thread 26 : len 7633 set 7633
# Thread 26 : exit
# Thread 29 : len 7773 set 7773
# Thread 29 : exit
# Thread 171 : len 5747 set 5747
# Thread 171 : exit
# Thread 81 : len 6301 set 6301
# Thread 81 : exit
# Thread 10 : len 6811 set 6811
# Thread 10 : exit
# Thread 58 : len 6924 set 6924
# Thread 58 : exit
# Thread 136 : len 6792 set 6792
# Thread 136 : exit
# Thread 54 : len 7583 set 7583Thread 161 : len 6470 set 6470
# Thread 54 : exit
#
# Thread 161 : exit
# Thread 57 : len 6883 set 6883
# Thread 57 : exit
# Thread 105 : len 6508 set 6508
# Thread 105 : exit
# Thread 133 : len 6253 set 6253
# Thread 133 : exit
# Thread 64 : len 7924 set 7924
# Thread 64 : exit
# Thread 175 : len 6564 set 6564
# Thread 175 : exit
# Thread 143 : len 6585 set 6585
# Thread 143 : exit
# Thread 118 : len 8220 set 8220
# Thread 118 : exit
# Thread 193 : len 6588 set 6588
# Thread 193 : exit
# Thread 172 : len 7027 set 7027
# Thread 172 : exit
# Thread 179 : len 5829 set 5829
# Thread 179 : exit
# Thread 173 : len 7023 set 7023
# Thread 173 : exit
# Thread 65 : len 8129 set 8129
# Thread 65 : exit
# Thread 25 : len 8742 set 8742
# Thread 25 : exit
# Thread 142 : len 8270 set 8270
# Thread 142 : exit
# Thread 79 : len 7838 set 7838
# Thread 79 : exit
# Thread 2 : len 6953 set 6953
# Thread 2 : exit
# Thread 176 : len 7963 set 7963
# Thread 176 : exit
# Thread 119 : len 8296 set 8296Thread 33 : len 9049 set 9049
# Thread 119 : exit
#
# Thread 33 : exit
# Thread 183 : len 9714 set 9714
# Thread 183 : exit
# Thread 144 : len 9014 set 9014
# Thread 144 : exit
# Thread 160 : len 8325 set 8325
# Thread 160 : exit
# Thread 7 : len 8832 set 8832
# Thread 7 : exit
# Thread 114 : len 10268 set 10268
# Thread 114 : exit
# Thread 37 : len 8699 set 8699
# Thread 37 : exit
# Thread 177 : len 8049 set 8049Thread 186 : len 8993 set 8993
# Thread 186 : exit
#
# Thread 177 : exit
# Thread 24 : len 9589 set 9589
# Thread 24 : exit
# Thread 94 : len 10321 set 10321
# Thread 94 : exit
# Thread 180 : len 8057 set 8057
# Thread 180 : exit
# Thread 165 : len 9268 set 9268
# Thread 165 : exit
# Thread 100 : len 15910 set 15910
# Thread 100 : exit
# Thread 52 : len 11753 set 11753
# Thread 52 : exit
# Thread 190 : len 11247 set 11247
# Thread 190 : exitThread 17 : len 9205 set 9205
# Thread 17 : exit
#
# Thread 99 : len 11787 set 11787
# Thread 99 : exit
# Thread 131 : len 10725 set 10725
# Thread 131 : exit
# Thread 80 : len 12257 set 12257
# Thread 80 : exit
# Thread 21 : len 13170 set 13170
# Thread 21 : exit
# Thread 60 : len 16662 set 16662
# Thread 60 : exit
# Thread 96 : len 10701 set 10701
# Thread 96 : exit
# Thread 104 : len 12556 set 12556
# Thread 104 : exit
# Thread 181 : len 9801 set 9801
# Thread 181 : exit
# Thread 46 : len 14018 set 14018
# Thread 46 : exit
# Thread 35 : len 10640 set 10640
# Thread 35 : exit
# Thread 84 : len 15155 set 15155
# Thread 84 : exit
# Thread 9 : len 14792 set 14792
# Thread 9 : exit
# Thread 141 : len 15017 set 15017
# Thread 141 : exit
# Thread 48 : len 12817 set 12817
# Thread 48 : exit
# Thread 27 : len 18186 set 18186Thread 149 : len 11885 set 11885
#
# Thread 149 : exit
# Thread 27 : exit
# Thread 162 : len 20715 set 20715
# Thread 162 : exit
# Thread 38 : len 16752 set 16752
# Thread 38 : exit
# Thread 153 : len 16261 set 16261
# Thread 153 : exit
# Thread 132 : len 13832 set 13832
# Thread 132 : exit
# Thread 187 : len 16314 set 16314
# Thread 187 : exit
# Thread 150 : len 12144 set 12144
# Thread 150 : exit
# Thread 154 : len 20472 set 20472
# Thread 154 : exit
# Thread 78 : len 14917 set 14917
# Thread 78 : exit
# Thread 125 : len 17147 set 17147
# Thread 125 : exit
# Thread 76 : len 17261 set 17261Thread 120 : len 15823 set 15823
# Thread 120 : exit
#
# Thread 76 : exit
# Thread 117 : len 16806 set 16806
# Thread 117 : exit
# Thread 163 : len 13412 set 13412
# Thread 163 : exit
# Thread 169 : len 21826 set 21826
# Thread 169 : exit
# Thread 59 : len 16785 set 16785
# Thread 59 : exit
# Thread 191 : len 19418 set 19418
# Thread 191 : exit
# Thread 121 : len 14578 set 14578
# Thread 121 : exit
# Thread 69 : len 16536 set 16536
# Thread 69 : exit
# Thread 151 : len 19868 set 19868Thread 16 : len 19317 set 19317
# Thread 151 : exit
#
# Thread 16 : exit
# Thread 85 : len 23603 set 23603
# Thread 85 : exit
# Thread 130 : len 24964 set 24964
# Thread 130 : exit
# Thread 184 : len 12378 set 12378Thread 51 : len 16649 set 16649
# Thread 51 : exit
#
# Thread 184 : exit
# Thread 53 : len 20497 set 20497
# Thread 53 : exit
# Thread 157 : len 14148 set 14148
# Thread 157 : exit
# Thread 111 : len 20671 set 20671
# Thread 111 : exit
# Thread 107 : len 18421 set 18421
# Thread 107 : exit
# Thread 158 : len 18589 set 18589
# Thread 158 : exit
# Thread 61 : len 22857 set 22857
# Thread 61 : exit
# Thread 129 : len 23258 set 23258
# Thread 129 : exit
# Thread 146 : len 19076 set 19076
# Thread 146 : exit
# Thread 74 : len 24054 set 24054
# Thread 74 : exit
# Thread 43 : len 16099 set 16099
# Thread 43 : exit
# Thread 6 : len 17470 set 17470
# Thread 6 : exit
# Thread 92 : len 23511 set 23511
# Thread 92 : exit
# Thread 82 : len 22434 set 22434
# Thread 82 : exit
# Thread 145 : len 22543 set 22543
# Thread 145 : exit
# Thread 73 : len 22660 set 22660
# Thread 73 : exit
# Thread 148 : len 24111 set 24111
# Thread 148 : exit
# Thread 127 : len 28115 set 28115
# Thread 127 : exit
# Thread 83 : len 33784 set 33784
# Thread 83 : exit
# Thread 12 : len 34898 set 34898
# Thread 12 : exit
# Thread 71 : len 31195 set 31195
# Thread 71 : exit
# Thread 185 : len 29193 set 29193
# Thread 185 : exit
# Thread 113 : len 39819 set 39819
# Thread 113 : exit
# 1822200/1822200 [==============================] - 5s 3us/step
# 100%|██████████| 1/1 [30:35<00:00, 1835.98s/it]
# Prec@k score: 0.9
#
# intersect
# {14561, 11363, 7526, 3302, 12072, 3401, 3436, 13168, 12626, 12372} 10
#
# union
# {14561, 11363, 7526, 3302, 12072, 3401, 3436, 13168, 12626, 12372} 10
#
# distinct rate
# 1.0

# %%
top_reasoning_paths = get_reasoning_paths(top_paths, truth_items)
worst_reasoning_paths = get_reasoning_paths(worst_paths, truth_items)

display(top_reasoning_paths)
print("=====================================================================================")
display(worst_reasoning_paths)

# %%
user_paths = generate_all_path_from_user("500302", max_seed_num=3, max_seed_ratio=0.3)
X_test, y_true = reformat_user_path(user_paths)
y_pred = model.predict(X_test, batch_size=2048, verbose=1)

# descending_path_score = sorted(zip(X_test, y_pred), key=lambda x: x[1], reverse=True)
top_paths, top_choosen_items = _get_top_k_items_with_score_pooling(X_test, y_pred, k=10, max_pooling_size=5, get_best=True)
# Out:
# 76731/76731 [==============================] - 0s 2us/step
